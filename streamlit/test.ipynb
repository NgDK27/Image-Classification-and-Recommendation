# %%
import tensorflow as tf
import numpy as np
# from tensorflow.keras.models import load_model
# from PIL import Image

# Load your model (replace 'your_model_path' with the actual path to your model)
model1 = tf.keras.models.load_model('../data/models/task-1-CNN.keras')
model3 = tf.keras.models.load_model('../data/models/task-3-CNN.keras')
# Out:
# WARNING:tensorflow:From c:\Users\SEUNGMIN\Documents\GitHub\Image-Classification-and-Recommendation\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\SEUNGMIN\Documents\GitHub\Image-Classification-and-Recommendation\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\SEUNGMIN\Documents\GitHub\Image-Classification-and-Recommendation\.venv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
model1.summary()

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 4)       112
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 4)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 8)       296
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 8)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        1168
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 32)        8224
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 64)        32832
#
#  global_max_pooling2d (Glob  (None, 64)                0
#  alMaxPooling2D)
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
# ...

# %%
print(model3.layers[-1].activation)
# Out:
# <function sigmoid at 0x0000019E24DC1C60>

# %%
from utils import load_classes

classes = load_classes('../data/label_encoders/class_encoder.npy')
print(classes)
# Out:
# WARNING:tensorflow:From c:\Users\SEUNGMIN\Documents\GitHub\Image-Classification-and-Recommendation\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ['beds', 'chairs', 'dressers', 'lamps', 'sofas', 'tables']

# %%
import pandas as pd

recommendations_df = pd.read_csv('../data/recommend/csv/recommendations.csv')

recommendations_df.head()
# Out:
#                                                 Path Class  Style        x0  \
# 0                  beds/Asian/19726asian-daybeds.jpg  beds  Asian  0.179309
# 1               beds/Asian/20109asian-panel-beds.jpg  beds  Asian  0.232647
# 2  beds/Asian/20750asian-comforters-and-comforter...  beds  Asian  0.096885
# 3             beds/Asian/2537asian-platform-beds.jpg  beds  Asian  0.068528
# 4             beds/Asian/2637asian-platform-beds.jpg  beds  Asian  0.153080
#
#          x1        x2        x3        x4        x5        x6        x7  \
# 0  0.265481 -0.185700 -0.022243 -0.089366 -0.047904 -0.048816 -0.007592
# 1  0.178083 -0.179546 -0.071229 -0.097339 -0.044400 -0.166813 -0.015090
# 2  0.163855 -0.124783  0.026223 -0.078047  0.002013 -0.135736 -0.068449
# 3  0.164794 -0.124503 -0.022786 -0.108601  0.023818 -0.102340 -0.087276
# 4  0.201729 -0.098292  0.012667 -0.107550  0.006911 -0.170126 -0.027986
#
#          x8        x9       x10       x11       x12       x13       x14  \
# ...
